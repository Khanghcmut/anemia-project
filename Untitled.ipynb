# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./anemia.csv')
df
# Out:
#       Gender  Hemoglobin   MCH  MCHC   MCV  Result
# 0          1        14.9  22.7  29.1  83.7       0
# 1          0        15.9  25.4  28.3  72.0       0
# 2          0         9.0  21.5  29.6  71.2       1
# 3          0        14.9  16.0  31.4  87.5       0
# 4          1        14.7  22.0  28.2  99.5       0
# ...      ...         ...   ...   ...   ...     ...
# 1416       0        10.6  25.4  28.2  82.9       1
# 1417       1        12.1  28.3  30.4  86.9       1
# 1418       1        13.1  17.7  28.1  80.7       1
# 1419       0        14.3  16.2  29.5  95.2       0
# 1420       0        11.8  21.2  28.4  98.1       1
#
# [1421 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      1421 non-null   int64
#  1   Hemoglobin  1421 non-null   float64
#  2   MCH         1421 non-null   float64
#  3   MCHC        1421 non-null   float64
#  4   MCV         1421 non-null   float64
#  5   Result      1421 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 66.7 KB

# %%
df.describe()
# Out:
#             Gender   Hemoglobin          MCH         MCHC          MCV  \
# count  1421.000000  1421.000000  1421.000000  1421.000000  1421.000000
# mean      0.520760    13.412738    22.905630    30.251232    85.523786
# std       0.499745     1.974546     3.969375     1.400898     9.636701
# min       0.000000     6.600000    16.000000    27.800000    69.400000
# 25%       0.000000    11.700000    19.400000    29.000000    77.300000
# 50%       1.000000    13.200000    22.700000    30.400000    85.300000
# 75%       1.000000    15.000000    26.200000    31.400000    94.200000
# max       1.000000    16.900000    30.000000    32.500000   101.600000
#
#             Result
# count  1421.000000
# mean      0.436312
# std       0.496102
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isna().sum()
# Out:
# Gender        0
# Hemoglobin    0
# MCH           0
# MCHC          0
# MCV           0
# Result        0
# dtype: int64

# %%
fig,ax=plt.subplots(1,2, figsize=(12,8))
df['Result'].value_counts().plot.pie(autopct='%1.2f%%',ax=ax[0],shadow=True,startangle=90,explode = [0.05, 0])
ax[0].set_title('percent of patient had amenia')
sns.countplot(data=df,x='Result',ax=ax[1])
plt.grid(linestyle='--',alpha=0.3)
ax[1].set_title('number of patient had amenia')
# Out:
# Text(0.5, 1.0, 'number of patient had amenia')

# %%
df.groupby(['Gender','Result'])['Result'].value_counts()
# Out:
# Gender  Result
# 0       0         473
#         1         208
# 1       0         328
#         1         412
# Name: count, dtype: int64

# %%
fig,ax=plt.subplots( figsize=(10,8))
sns.countplot(data=df,x='Gender',ax=ax,hue='Result')
plt.legend(['not anemic','anemic'])

# %%
f,ax=plt.subplots(figsize=(10,7))
df[['Gender','Result']].groupby(['Gender']).mean().plot.bar(ax=ax)
plt.xticks(rotation = 0)
ax.set_title('Having Anemia vs Gender proportion')
df[['Gender','Result']].groupby(['Gender']).mean()
# Out:
#           Result
# Gender
# 0       0.305433
# 1       0.556757

# %%
f,ax=plt.subplots(figsize=(10,7));

sns.kdeplot(data=df,x='Hemoglobin',hue='Gender',bw_adjust=1.5,fill=True,alpha=0.3);
plt.legend(['male','female'])
plt.grid(True, alpha=0.3, linestyle="--")
plt.xticks(rotation = 0)
plt.title('kde plot of hemoglobin by sex')
# Out:
# Text(0.5, 1.0, 'kde plot of hemoglobin by sex')

# %%
f,ax=plt.subplots(figsize=(10,7));

sns.kdeplot(data=df,x='Hemoglobin',hue='Result',bw_adjust=1.5,fill=True,alpha=0.3);
plt.legend(['anemic','not anemic'])
plt.grid(True, alpha=0.3, linestyle="--")
plt.xticks(rotation = 0)
plt.title('kde plot of hemoglobin of people had anemic and not anemic')
# Out:
# Text(0.5, 1.0, 'kde plot of hemoglobin of people had anemic and not anemic')

# %%
f,ax=plt.subplots(figsize=(10,7));

sns.kdeplot(data=df,x='Hemoglobin',y='MCH',hue='Result',bw_adjust=1.5,fill=True);

plt.grid(True, alpha=0.3, linestyle="--")

plt.xticks(rotation = 0)
# Out:
# (array([ 4.,  6.,  8., 10., 12., 14., 16., 18., 20.]),
#  [Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20')])

# %%
f,ax=plt.subplots(figsize=(10,7));

sns.kdeplot(data=df,x='Hemoglobin',y='MCHC',hue='Result',bw_adjust=1.5,fill=True);

plt.grid(True, alpha=0.3, linestyle="--")

plt.xticks(rotation = 0)
# Out:
# (array([ 4.,  6.,  8., 10., 12., 14., 16., 18., 20.]),
#  [Text(4.0, 0, '4'),
#   Text(6.0, 0, '6'),
#   Text(8.0, 0, '8'),
#   Text(10.0, 0, '10'),
#   Text(12.0, 0, '12'),
#   Text(14.0, 0, '14'),
#   Text(16.0, 0, '16'),
#   Text(18.0, 0, '18'),
#   Text(20.0, 0, '20')])

# %%
f,ax=plt.subplots(figsize=(10,7));

sns.kdeplot(data=df,x='MCH',y='MCHC',bw_adjust=1.5,fill=True);

plt.grid(True, alpha=0.3, linestyle="--")

plt.xticks(rotation = 0)
# Out:
# (array([10., 15., 20., 25., 30., 35., 40.]),
#  [Text(10.0, 0, '10'),
#   Text(15.0, 0, '15'),
#   Text(20.0, 0, '20'),
#   Text(25.0, 0, '25'),
#   Text(30.0, 0, '30'),
#   Text(35.0, 0, '35'),
#   Text(40.0, 0, '40')])

# %%
dfcorr=df.corr()

dfcorrup=np.triu(dfcorr)
dfcorr=dfcorr.iloc[1:,:-1]
dfcorrup=dfcorrup[1:,:-1]

# %%
sns.heatmap(dfcorr,mask=dfcorrup,annot=True,cmap='coolwarm',linewidths=0.2,cbar=False)
plt.yticks(rotation=0)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5]),
#  [Text(0, 0.5, 'Hemoglobin'),
#   Text(0, 1.5, 'MCH'),
#   Text(0, 2.5, 'MCHC'),
#   Text(0, 3.5, 'MCV'),
#   Text(0, 4.5, 'Result')])

# %%
from sklearn import preprocessing

d = preprocessing.normalize(df.iloc[:,1:-1], axis=0)
scaled_df = pd.DataFrame(d, columns=["Hemoglobin", "MCH", "MCHC", "MCV"])
scaled_df.head()
# Out:
#    Hemoglobin       MCH      MCHC       MCV
# 0    0.029155  0.025904  0.025491  0.025799
# 1    0.031112  0.028985  0.024790  0.022193
# 2    0.017611  0.024535  0.025929  0.021946
# 3    0.029155  0.018258  0.027506  0.026970
# 4    0.028764  0.025105  0.024703  0.030669

# %%
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix
from xgboost import XGBClassifier#XGBcalssifier

# %%
x=df.iloc[:,:-1]
y=df.Result
x.shape
# Out:
# (1421, 5)

# %%
xtrain,xtest, ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(xtrain,ytrain)
prediction1=model.predict(xtest)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,ytest))
# Out:
# Accuracy for rbf SVM is  0.9601873536299765

# %%
decision_tree = DecisionTreeClassifier (criterion = 'entropy', max_depth = 10, random_state=2000)
decision_tree.fit(xtrain,ytrain)
decision_tree.score(xtest, ytest)
# Out:
# 1.0

# %%
from sklearn.model_selection import StratifiedKFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction
seed=200
kfold = StratifiedKFold(10, shuffle=True, random_state=seed) # k=10, split the data into 10 equal parts

cv_mean=[]
accuracy=[]
std=[]
classifier=[]
models=[svm.SVC(kernel='linear'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(random_state=seed),GaussianNB(),RandomForestClassifier(random_state=seed),XGBClassifier (use_label_encoder=False, eval_metric='logloss', random_state=seed)]
for model in models:
    model_name = model.__class__.__name__
    if model_name not in(classifier):
        classifier.append(model_name)
    cv_result = cross_val_score(model,x,y, cv = kfold,scoring = 'average_precision')
    cv_result=cv_result
    cv_mean.append(round(cv_result.mean(),2))
    std.append(round(cv_result.std(),2))
    accuracy.append(cv_result)
new_models_dataframe=pd.DataFrame({'ML model':classifier,'accuracy_score':cv_mean,'std':std})
new_models_dataframe
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
# ...

# %%
entries=[]
for model in models:
    model_name = model.__class__.__name__
    kfold = StratifiedKFold(50, shuffle=True, random_state=seed)
    scores = cross_val_score(model, x,y, scoring='average_precision', cv=kfold)
    for fold_idx, score in enumerate(scores):
        entries.append([model_name, fold_idx, score])
cv_df = pd.DataFrame(entries, columns= [ 'model_name','fold id','accuracy_score' ])
sns.boxplot(cv_df,x='model_name',y='accuracy_score',showmeans=True)
plt.xticks(rotation=60)
cv_df
# Out:
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/khangphan/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
XGBClassifier_test_df=cv_df[cv_df['model_name']=='XGBClassifier']
XGBClassifier_test_df.describe()
